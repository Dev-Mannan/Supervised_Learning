# %%
print('This is a notebook with hyperparameterised code')
# Out:
# This is a notebook with hyperparameterised code

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
## Reading the dataset using pandas
dataset = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv',header=1)
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
## Data cleaning Process
## checking missing values

dataset[dataset.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
## The dataset is converted into two sets based on the regions from 122th index , we can make a new column based on the regions

## 1. Sidi-Bel Abbes Region
## 2. bejaire Region

## add new column with the dataset

# %%
dataset.loc[:122,'Region'] = 0
dataset.loc[122:,'Region'] = 1
df = dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.0+ KB

# %%
df[['Region']] = df[['Region']].astype(int)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
## Removing the null values
df.dropna().reset_index(drop=True)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          0
# ...

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df = df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
df = df.drop(122).reset_index(drop=True)
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
## fix spaces in columns names
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
## change the required columns as integer data type
df[['day', 'month', 'year', 'Temperature','RH', 'Ws']] = df[['day', 'month', 'year', 'Temperature','RH', 'Ws']].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int32
#  1   month        244 non-null    int32
#  2   year         244 non-null    int32
#  3   Temperature  244 non-null    int32
#  4   RH           244 non-null    int32
#  5   Ws           244 non-null    int32
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       244 non-null    int32
# dtypes: int32(7), object(8)
# memory usage: 22.1+ KB

# %%
# Identify non-numeric values in the object-type columns
objects = [features for features in df.columns if df[features].dtype == 'O']

for col in objects:
    if col != 'Classes':  # Skip 'Classes' as per your logic
        print(f"Non-numeric values in column '{col}':")
        non_numeric = df[~df[col].str.replace('.', '', regex=False).str.isnumeric()]
        print(non_numeric[[col]])
        print()
# Out:
# Non-numeric values in column 'DC':
#          DC
# 165  14.6 9
#
# Non-numeric values in column 'ISI':
# Empty DataFrame
# Columns: [ISI]
# Index: []
#
# Non-numeric values in column 'BUI':
# Empty DataFrame
# Columns: [BUI]
# Index: []
#
# Non-numeric values in column 'FWI':
#          FWI
# 11      7.1
# 165  fire

# %%
# Clean the data by removing spaces and non-numeric characters
for col in objects:
    if col != 'Classes':
        # Replace spaces with dots if necessary (or remove spaces if they are not decimal points)
        df[col] = df[col].str.replace(' ', '.', regex=False)
        
        # Remove any remaining non-numeric characters
        df[col] = df[col].str.replace(r'[^\d.]+', '', regex=True)

        # Convert the cleaned column to float
        df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
objects
# Out:
# ['DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int32
#  1   month        244 non-null    int32
#  2   year         244 non-null    int32
#  3   Temperature  244 non-null    int32
#  4   RH           244 non-null    int32
#  5   Ws           244 non-null    int32
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          242 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       244 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.1+ KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  244.000000  244.000000   244.0   244.000000  244.000000  244.000000
# mean    15.754098    7.500000  2012.0    32.172131   61.938525   15.504098
# std      8.825059    1.112961     0.0     3.633843   14.884200    2.810178
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.000000   14.000000
# 50%     16.000000    7.500000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.250000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  244.000000  244.000000  244.000000  243.000000  244.000000  244.000000
# mean     0.760656   77.887705   14.673361   49.430864    4.774180   16.664754
# ...

# %%
## let save the cleaned dataset
df.to_csv('Algerian_forest_fires_cleaned_dataset.csv', index=False)

# %%
## Exploratory data analysis
df_copy = df

# %%
df_copy = df.drop(['day','month','year'], axis=1)
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_copy['Classes']=np.where(df_copy['Classes']=='not fire   ',0,1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    143
# 0    101
# Name: count, dtype: int64

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  244 non-null    int32
#  1   RH           244 non-null    int32
#  2   Ws           244 non-null    int32
#  3   Rain         244 non-null    float64
#  4   FFMC         244 non-null    float64
#  5   DMC          244 non-null    float64
#  6   DC           243 non-null    float64
#  7   ISI          244 non-null    float64
#  8   BUI          244 non-null    float64
#  9   FWI          242 non-null    float64
#  10  Classes      244 non-null    int32
#  11  Region       244 non-null    int32
# dtypes: float64(7), int32(5)
# memory usage: 18.2 KB

# %%
import seaborn as sns

# %%
##plot density for all features
plt.style.use('classic')
df_copy.hist(bins=50, figsize=(20,15))
plt.show()

# %%
## Percentage for pie chart
df_copy['Classes'].value_counts(normalize=True)*100
# Out:
# Classes
# 1    58.606557
# 0    41.393443
# Name: proportion, dtype: float64

# %%
## ploting pie chart
classlabels=['Fire','Not Fire']
plt.figure(figsize=(10,6))
plt.pie(df_copy['Classes'].value_counts(),labels=classlabels,autopct='%1.1f%%')
plt.title("pie chart")
plt.show()

# %%
## correlation matrix
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.654443 -0.278132 -0.326786  0.677491  0.483105
# RH             -0.654443  1.000000  0.236084  0.222968 -0.645658 -0.405133
# Ws             -0.278132  0.236084  1.000000  0.170169 -0.163255 -0.001246
# Rain           -0.326786  0.222968  0.170169  1.000000 -0.544045 -0.288548
# FFMC            0.677491 -0.645658 -0.163255 -0.544045  1.000000  0.602391
# DMC             0.483105 -0.405133 -0.001246 -0.288548  0.602391  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.607551 -0.690637  0.015248 -0.347105  0.739730  0.674499
# BUI             0.455504 -0.348587  0.029756 -0.299171  0.589652  0.982073
# FWI             0.570143 -0.582983  0.032428 -0.324506  0.691381  0.875876
# Classes         0.457499 -0.416340 -0.050696 -0.247604  0.709060  0.556322
# ...

# %%
sns.heatmap(df_copy.corr(),annot=True)
# Out:
# <Axes: >

# %%
## Box plots 
sns.boxplot(df['FWI'])
# Out:
# <Axes: ylabel='FWI'>

# %%
## Monthly Fire Analysis
dftemp=df.loc[df['Region']==1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
# Out:
# <Axes: xlabel='month', ylabel='count'>
